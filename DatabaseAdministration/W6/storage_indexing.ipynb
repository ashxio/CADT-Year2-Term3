# %%
import pandas as pd
import random

# %% [markdown]
# ## Generate and Insert Data into Database - Facebook Users - Generate 6 000 000 records

# %%
import random
import string
import mysql.connector  # Replace with your database connector library (e.g., psycopg2 for PostgreSQL)

# Database connection details (replace with your credentials)
DB_HOST = "localhost"
DB_USER = "root"
DB_PASSWORD = "BigDickDaddy123$"
DB_NAME = "big_data_db"

# Function to generate random data (you can customize this)
def generate_data():
    countries = [
        "Australia", "Brunei", 
        "Cambodia", "Canada", 
        "Vietnam", "France", 
        "Germany", "India", 
        "Indonesia", "Italy", 
        "Japan", "Laos", 
        "Malaysia", "Myanmar", 
        "Norway", "Singapore",
        "Spain", "Thailand", 
        "United Kingdom", "United States"
    ]
    name = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
    email = f"{name.lower()}@{random.randint(1, 100)}.com"
    age = random.randint(18, 65)
    country = random.choice(countries)
    return name, email, age, country

# Connect to the database
try:
    connection = mysql.connector.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWORD, database=DB_NAME)
    cursor = connection.cursor()
except mysql.connector.Error as err:
    print("Error connecting to database:", err)
    exit()

# Create table if it doesn't exist (replace with your table schema)
create_table_query = """
CREATE TABLE IF NOT EXISTS facebook_users (
id INT AUTO_INCREMENT PRIMARY KEY,
name VARCHAR(255) NOT NULL,
email VARCHAR(255) NOT NULL UNIQUE,
age INT NOT NULL,
country VARCHAR(255) NOT NULL
)
"""
cursor.execute(create_table_query)
connection.commit()

# Generate and insert data
print('Start inserting ...')
insertion_amount = 1000
num_records = 6000
i = 0
for k in range(insertion_amount):
    for _ in range(num_records):
        name, email, age, country = generate_data()
        insert_query = """
        INSERT INTO facebook_users (name, email, age, country)
        VALUES (%s, %s, %s, %s)
        """
        cursor.execute(insert_query, (name, email, age, country))
    connection.commit()
    i = i + 1
    print('Insertion round', i, num_records, 'records.')

print(f"Successfully inserted {num_records*insertion_amount} records into the database.")

# Close the connection
cursor.close()
connection.close()

print('Finished inserting!!!')
# Out:
# Start inserting ...
# Insertion round 1 6000 records.
# Insertion round 2 6000 records.
# Insertion round 3 6000 records.
# Insertion round 4 6000 records.
# Insertion round 5 6000 records.
# Insertion round 6 6000 records.
# Insertion round 7 6000 records.
# Insertion round 8 6000 records.
# Insertion round 9 6000 records.
# Insertion round 10 6000 records.
# Insertion round 11 6000 records.
# Insertion round 12 6000 records.
# Insertion round 13 6000 records.
# Insertion round 14 6000 records.
# Insertion round 15 6000 records.
# Insertion round 16 6000 records.
# Insertion round 17 6000 records.
# Insertion round 18 6000 records.
# Insertion round 19 6000 records.
# Insertion round 20 6000 records.
# Insertion round 21 6000 records.
# Insertion round 22 6000 records.
# Insertion round 23 6000 records.
# Insertion round 24 6000 records.
# Insertion round 25 6000 records.
# Insertion round 26 6000 records.
# Insertion round 27 6000 records.
# Insertion round 28 6000 records.
# Insertion round 29 6000 records.
# Insertion round 30 6000 records.
# Insertion round 31 6000 records.
# Insertion round 32 6000 records.
# Insertion round 33 6000 records.
# Insertion round 34 6000 records.
# Insertion round 35 6000 records.
# Insertion round 36 6000 records.
# Insertion round 37 6000 records.
# Insertion round 38 6000 records.
# Insertion round 39 6000 records.
# Insertion round 40 6000 records.
# Insertion round 41 6000 records.
# Insertion round 42 6000 records.
# Insertion round 43 6000 records.
# Insertion round 44 6000 records.
# Insertion round 45 6000 records.
# Insertion round 46 6000 records.
# Insertion round 47 6000 records.
# Insertion round 48 6000 records.
# Insertion round 49 6000 records.
# Insertion round 50 6000 records.
# Insertion round 51 6000 records.
# Insertion round 52 6000 records.
# Insertion round 53 6000 records.
# Insertion round 54 6000 records.
# Insertion round 55 6000 records.
# Insertion round 56 6000 records.
# Insertion round 57 6000 records.
# Insertion round 58 6000 records.
# Insertion round 59 6000 records.
# Insertion round 60 6000 records.
# Insertion round 61 6000 records.
# Insertion round 62 6000 records.
# Insertion round 63 6000 records.
# Insertion round 64 6000 records.
# Insertion round 65 6000 records.
# Insertion round 66 6000 records.
# Insertion round 67 6000 records.
# Insertion round 68 6000 records.
# Insertion round 69 6000 records.
# Insertion round 70 6000 records.
# Insertion round 71 6000 records.
# Insertion round 72 6000 records.
# Insertion round 73 6000 records.
# Insertion round 74 6000 records.
# Insertion round 75 6000 records.
# Insertion round 76 6000 records.
# Insertion round 77 6000 records.
# Insertion round 78 6000 records.
# Insertion round 79 6000 records.
# Insertion round 80 6000 records.
# Insertion round 81 6000 records.
# Insertion round 82 6000 records.
# Insertion round 83 6000 records.
# Insertion round 84 6000 records.
# Insertion round 85 6000 records.
# Insertion round 86 6000 records.
# Insertion round 87 6000 records.
# Insertion round 88 6000 records.
# Insertion round 89 6000 records.
# Insertion round 90 6000 records.
# Insertion round 91 6000 records.
# Insertion round 92 6000 records.
# Insertion round 93 6000 records.
# Insertion round 94 6000 records.
# Insertion round 95 6000 records.
# Insertion round 96 6000 records.
# Insertion round 97 6000 records.
# Insertion round 98 6000 records.
# Insertion round 99 6000 records.
# Insertion round 100 6000 records.
# Insertion round 101 6000 records.
# Insertion round 102 6000 records.
# Insertion round 103 6000 records.
# Insertion round 104 6000 records.
# Insertion round 105 6000 records.
# Insertion round 106 6000 records.
# Insertion round 107 6000 records.
# Insertion round 108 6000 records.
# Insertion round 109 6000 records.
# Insertion round 110 6000 records.
# Insertion round 111 6000 records.
# Insertion round 112 6000 records.
# Insertion round 113 6000 records.
# Insertion round 114 6000 records.
# Insertion round 115 6000 records.
# Insertion round 116 6000 records.
# Insertion round 117 6000 records.
# Insertion round 118 6000 records.
# Insertion round 119 6000 records.
# Insertion round 120 6000 records.
# Insertion round 121 6000 records.
# Insertion round 122 6000 records.
# Insertion round 123 6000 records.
# Insertion round 124 6000 records.
# Insertion round 125 6000 records.
# Insertion round 126 6000 records.
# Insertion round 127 6000 records.
# Insertion round 128 6000 records.
# Insertion round 129 6000 records.
# Insertion round 130 6000 records.
# Insertion round 131 6000 records.
# Insertion round 132 6000 records.
# Insertion round 133 6000 records.
# Insertion round 134 6000 records.
# Insertion round 135 6000 records.
# Insertion round 136 6000 records.
# Insertion round 137 6000 records.
# Insertion round 138 6000 records.
# Insertion round 139 6000 records.
# Insertion round 140 6000 records.
# Insertion round 141 6000 records.
# Insertion round 142 6000 records.
# Insertion round 143 6000 records.
# Insertion round 144 6000 records.
# Insertion round 145 6000 records.
# Insertion round 146 6000 records.
# Insertion round 147 6000 records.
# Insertion round 148 6000 records.
# Insertion round 149 6000 records.
# Insertion round 150 6000 records.
# Insertion round 151 6000 records.
# Insertion round 152 6000 records.
# Insertion round 153 6000 records.
# Insertion round 154 6000 records.
# Insertion round 155 6000 records.
# Insertion round 156 6000 records.
# Insertion round 157 6000 records.
# Insertion round 158 6000 records.
# Insertion round 159 6000 records.
# Insertion round 160 6000 records.
# Insertion round 161 6000 records.
# Insertion round 162 6000 records.
# Insertion round 163 6000 records.
# Insertion round 164 6000 records.
# Insertion round 165 6000 records.
# Insertion round 166 6000 records.
# Insertion round 167 6000 records.
# Insertion round 168 6000 records.
# Insertion round 169 6000 records.
# Insertion round 170 6000 records.
# Insertion round 171 6000 records.
# Insertion round 172 6000 records.
# Insertion round 173 6000 records.
# Insertion round 174 6000 records.
# Insertion round 175 6000 records.
# Insertion round 176 6000 records.
# Insertion round 177 6000 records.
# Insertion round 178 6000 records.
# Insertion round 179 6000 records.
# Insertion round 180 6000 records.
# Insertion round 181 6000 records.
# Insertion round 182 6000 records.
# Insertion round 183 6000 records.
# Insertion round 184 6000 records.
# Insertion round 185 6000 records.
# Insertion round 186 6000 records.
# Insertion round 187 6000 records.
# Insertion round 188 6000 records.
# Insertion round 189 6000 records.
# Insertion round 190 6000 records.
# Insertion round 191 6000 records.
# Insertion round 192 6000 records.
# Insertion round 193 6000 records.
# Insertion round 194 6000 records.
# Insertion round 195 6000 records.
# Insertion round 196 6000 records.
# Insertion round 197 6000 records.
# Insertion round 198 6000 records.
# Insertion round 199 6000 records.
# Insertion round 200 6000 records.
# Insertion round 201 6000 records.
# Insertion round 202 6000 records.
# Insertion round 203 6000 records.
# Insertion round 204 6000 records.
# Insertion round 205 6000 records.
# Insertion round 206 6000 records.
# Insertion round 207 6000 records.
# Insertion round 208 6000 records.
# Insertion round 209 6000 records.
# Insertion round 210 6000 records.
# Insertion round 211 6000 records.
# Insertion round 212 6000 records.
# Insertion round 213 6000 records.
# Insertion round 214 6000 records.
# Insertion round 215 6000 records.
# Insertion round 216 6000 records.
# Insertion round 217 6000 records.
# Insertion round 218 6000 records.
# Insertion round 219 6000 records.
# Insertion round 220 6000 records.
# Insertion round 221 6000 records.
# Insertion round 222 6000 records.
# Insertion round 223 6000 records.
# Insertion round 224 6000 records.
# Insertion round 225 6000 records.
# Insertion round 226 6000 records.
# Insertion round 227 6000 records.
# Insertion round 228 6000 records.
# Insertion round 229 6000 records.
# Insertion round 230 6000 records.
# Insertion round 231 6000 records.
# Insertion round 232 6000 records.
# Insertion round 233 6000 records.
# Insertion round 234 6000 records.
# Insertion round 235 6000 records.
# Insertion round 236 6000 records.
# Insertion round 237 6000 records.
# Insertion round 238 6000 records.
# Insertion round 239 6000 records.
# Insertion round 240 6000 records.
# Insertion round 241 6000 records.
# Insertion round 242 6000 records.
# Insertion round 243 6000 records.
# Insertion round 244 6000 records.
# Insertion round 245 6000 records.
# Insertion round 246 6000 records.
# Insertion round 247 6000 records.
# Insertion round 248 6000 records.
# Insertion round 249 6000 records.
# Insertion round 250 6000 records.
# Insertion round 251 6000 records.
# Insertion round 252 6000 records.
# Insertion round 253 6000 records.
# Insertion round 254 6000 records.
# Insertion round 255 6000 records.
# Insertion round 256 6000 records.
# Insertion round 257 6000 records.
# Insertion round 258 6000 records.
# Insertion round 259 6000 records.
# Insertion round 260 6000 records.
# Insertion round 261 6000 records.
# Insertion round 262 6000 records.
# Insertion round 263 6000 records.
# Insertion round 264 6000 records.
# Insertion round 265 6000 records.
# Insertion round 266 6000 records.
# Insertion round 267 6000 records.
# Insertion round 268 6000 records.
# Insertion round 269 6000 records.
# Insertion round 270 6000 records.
# Insertion round 271 6000 records.
# Insertion round 272 6000 records.
# Insertion round 273 6000 records.
# Insertion round 274 6000 records.
# Insertion round 275 6000 records.
# Insertion round 276 6000 records.
# Insertion round 277 6000 records.
# Insertion round 278 6000 records.
# Insertion round 279 6000 records.
# Insertion round 280 6000 records.
# Insertion round 281 6000 records.
# Insertion round 282 6000 records.
# Insertion round 283 6000 records.
# Insertion round 284 6000 records.
# Insertion round 285 6000 records.
# Insertion round 286 6000 records.
# Insertion round 287 6000 records.
# Insertion round 288 6000 records.
# Insertion round 289 6000 records.
# Insertion round 290 6000 records.
# Insertion round 291 6000 records.
# Insertion round 292 6000 records.
# Insertion round 293 6000 records.
# Insertion round 294 6000 records.
# Insertion round 295 6000 records.
# Insertion round 296 6000 records.
# Insertion round 297 6000 records.
# Insertion round 298 6000 records.
# Insertion round 299 6000 records.
# Insertion round 300 6000 records.
# Insertion round 301 6000 records.
# Insertion round 302 6000 records.
# Insertion round 303 6000 records.
# Insertion round 304 6000 records.
# Insertion round 305 6000 records.
# Insertion round 306 6000 records.
# Insertion round 307 6000 records.
# Insertion round 308 6000 records.
# Insertion round 309 6000 records.
# Insertion round 310 6000 records.
# Insertion round 311 6000 records.
# Insertion round 312 6000 records.
# Insertion round 313 6000 records.
# Insertion round 314 6000 records.
# Insertion round 315 6000 records.
# Insertion round 316 6000 records.
# Insertion round 317 6000 records.
# Insertion round 318 6000 records.
# Insertion round 319 6000 records.
# Insertion round 320 6000 records.
# Insertion round 321 6000 records.
# Insertion round 322 6000 records.
# Insertion round 323 6000 records.
# Insertion round 324 6000 records.
# Insertion round 325 6000 records.
# Insertion round 326 6000 records.
# Insertion round 327 6000 records.
# Insertion round 328 6000 records.
# Insertion round 329 6000 records.
# Insertion round 330 6000 records.
# Insertion round 331 6000 records.
# Insertion round 332 6000 records.
# Insertion round 333 6000 records.
# Insertion round 334 6000 records.
# Insertion round 335 6000 records.
# Insertion round 336 6000 records.
# Insertion round 337 6000 records.
# Insertion round 338 6000 records.
# Insertion round 339 6000 records.
# Insertion round 340 6000 records.
# Insertion round 341 6000 records.
# Insertion round 342 6000 records.
# Insertion round 343 6000 records.
# Insertion round 344 6000 records.
# Insertion round 345 6000 records.
# Insertion round 346 6000 records.
# Insertion round 347 6000 records.
# Insertion round 348 6000 records.
# Insertion round 349 6000 records.
# Insertion round 350 6000 records.
# Insertion round 351 6000 records.
# Insertion round 352 6000 records.
# Insertion round 353 6000 records.
# Insertion round 354 6000 records.
# Insertion round 355 6000 records.
# Insertion round 356 6000 records.
# Insertion round 357 6000 records.
# Insertion round 358 6000 records.
# Insertion round 359 6000 records.
# Insertion round 360 6000 records.
# Insertion round 361 6000 records.
# Insertion round 362 6000 records.
# Insertion round 363 6000 records.
# Insertion round 364 6000 records.
# Insertion round 365 6000 records.
# Insertion round 366 6000 records.
# Insertion round 367 6000 records.
# Insertion round 368 6000 records.
# Insertion round 369 6000 records.
# Insertion round 370 6000 records.
# Insertion round 371 6000 records.
# Insertion round 372 6000 records.
# Insertion round 373 6000 records.
# Insertion round 374 6000 records.
# Insertion round 375 6000 records.
# Insertion round 376 6000 records.
# Insertion round 377 6000 records.
# Insertion round 378 6000 records.
# Insertion round 379 6000 records.
# Insertion round 380 6000 records.
# Insertion round 381 6000 records.
# Insertion round 382 6000 records.
# Insertion round 383 6000 records.
# Insertion round 384 6000 records.
# Insertion round 385 6000 records.
# Insertion round 386 6000 records.
# Insertion round 387 6000 records.
# Insertion round 388 6000 records.
# Insertion round 389 6000 records.
# Insertion round 390 6000 records.
# Insertion round 391 6000 records.
# Insertion round 392 6000 records.
# Insertion round 393 6000 records.
# Insertion round 394 6000 records.
# Insertion round 395 6000 records.
# Insertion round 396 6000 records.
# Insertion round 397 6000 records.
# Insertion round 398 6000 records.
# Insertion round 399 6000 records.
# Insertion round 400 6000 records.
# Insertion round 401 6000 records.
# Insertion round 402 6000 records.
# Insertion round 403 6000 records.
# Insertion round 404 6000 records.
# Insertion round 405 6000 records.
# Insertion round 406 6000 records.
# Insertion round 407 6000 records.
# Insertion round 408 6000 records.
# Insertion round 409 6000 records.
# Insertion round 410 6000 records.
# Insertion round 411 6000 records.
# Insertion round 412 6000 records.
# Insertion round 413 6000 records.
# Insertion round 414 6000 records.
# Insertion round 415 6000 records.
# Insertion round 416 6000 records.
# Insertion round 417 6000 records.
# Insertion round 418 6000 records.
# Insertion round 419 6000 records.
# Insertion round 420 6000 records.
# Insertion round 421 6000 records.
# Insertion round 422 6000 records.
# Insertion round 423 6000 records.
# Insertion round 424 6000 records.
# Insertion round 425 6000 records.
# Insertion round 426 6000 records.
# Insertion round 427 6000 records.
# Insertion round 428 6000 records.
# Insertion round 429 6000 records.
# Insertion round 430 6000 records.
# Insertion round 431 6000 records.
# Insertion round 432 6000 records.
# Insertion round 433 6000 records.
# Insertion round 434 6000 records.
# Insertion round 435 6000 records.
# Insertion round 436 6000 records.
# Insertion round 437 6000 records.
# Insertion round 438 6000 records.
# Insertion round 439 6000 records.
# Insertion round 440 6000 records.
# Insertion round 441 6000 records.
# Insertion round 442 6000 records.
# Insertion round 443 6000 records.
# Insertion round 444 6000 records.
# Insertion round 445 6000 records.
# Insertion round 446 6000 records.
# Insertion round 447 6000 records.
# Insertion round 448 6000 records.
# Insertion round 449 6000 records.
# Insertion round 450 6000 records.
# Insertion round 451 6000 records.
# Insertion round 452 6000 records.
# Insertion round 453 6000 records.
# Insertion round 454 6000 records.
# Insertion round 455 6000 records.
# Insertion round 456 6000 records.
# Insertion round 457 6000 records.
# Insertion round 458 6000 records.
# Insertion round 459 6000 records.
# Insertion round 460 6000 records.
# Insertion round 461 6000 records.
# Insertion round 462 6000 records.
# Insertion round 463 6000 records.
# Insertion round 464 6000 records.
# Insertion round 465 6000 records.
# Insertion round 466 6000 records.
# Insertion round 467 6000 records.
# Insertion round 468 6000 records.
# Insertion round 469 6000 records.
# Insertion round 470 6000 records.
# Insertion round 471 6000 records.
# Insertion round 472 6000 records.
# Insertion round 473 6000 records.
# Insertion round 474 6000 records.
# Insertion round 475 6000 records.
# Insertion round 476 6000 records.
# Insertion round 477 6000 records.
# Insertion round 478 6000 records.
# Insertion round 479 6000 records.
# Insertion round 480 6000 records.
# Insertion round 481 6000 records.
# Insertion round 482 6000 records.
# Insertion round 483 6000 records.
# Insertion round 484 6000 records.
# Insertion round 485 6000 records.
# Insertion round 486 6000 records.
# Insertion round 487 6000 records.
# Insertion round 488 6000 records.
# Insertion round 489 6000 records.
# Insertion round 490 6000 records.
# Insertion round 491 6000 records.
# Insertion round 492 6000 records.
# Insertion round 493 6000 records.
# Insertion round 494 6000 records.
# Insertion round 495 6000 records.
# Insertion round 496 6000 records.
# Insertion round 497 6000 records.
# Insertion round 498 6000 records.
# Insertion round 499 6000 records.
# Insertion round 500 6000 records.
# Insertion round 501 6000 records.
# Insertion round 502 6000 records.
# Insertion round 503 6000 records.
# Insertion round 504 6000 records.
# Insertion round 505 6000 records.
# Insertion round 506 6000 records.
# Insertion round 507 6000 records.
# Insertion round 508 6000 records.
# Insertion round 509 6000 records.
# Insertion round 510 6000 records.
# Insertion round 511 6000 records.
# Insertion round 512 6000 records.
# Insertion round 513 6000 records.
# Insertion round 514 6000 records.
# Insertion round 515 6000 records.
# Insertion round 516 6000 records.
# Insertion round 517 6000 records.
# Insertion round 518 6000 records.
# Insertion round 519 6000 records.
# Insertion round 520 6000 records.
# Insertion round 521 6000 records.
# Insertion round 522 6000 records.
# Insertion round 523 6000 records.
# Insertion round 524 6000 records.
# Insertion round 525 6000 records.
# Insertion round 526 6000 records.
# Insertion round 527 6000 records.
# Insertion round 528 6000 records.
# Insertion round 529 6000 records.
# Insertion round 530 6000 records.
# Insertion round 531 6000 records.
# Insertion round 532 6000 records.
# Insertion round 533 6000 records.
# Insertion round 534 6000 records.
# Insertion round 535 6000 records.
# Insertion round 536 6000 records.
# Insertion round 537 6000 records.
# Insertion round 538 6000 records.
# Insertion round 539 6000 records.
# Insertion round 540 6000 records.
# Insertion round 541 6000 records.
# Insertion round 542 6000 records.
# Insertion round 543 6000 records.
# Insertion round 544 6000 records.
# Insertion round 545 6000 records.
# Insertion round 546 6000 records.
# Insertion round 547 6000 records.
# Insertion round 548 6000 records.
# Insertion round 549 6000 records.
# Insertion round 550 6000 records.
# Insertion round 551 6000 records.
# Insertion round 552 6000 records.
# Insertion round 553 6000 records.
# Insertion round 554 6000 records.
# Insertion round 555 6000 records.
# Insertion round 556 6000 records.
# Insertion round 557 6000 records.
# Insertion round 558 6000 records.
# Insertion round 559 6000 records.
# Insertion round 560 6000 records.
# Insertion round 561 6000 records.
# Insertion round 562 6000 records.
# Insertion round 563 6000 records.
# Insertion round 564 6000 records.
# Insertion round 565 6000 records.
# Insertion round 566 6000 records.
# Insertion round 567 6000 records.
# Insertion round 568 6000 records.
# Insertion round 569 6000 records.
# Insertion round 570 6000 records.
# Insertion round 571 6000 records.
# Insertion round 572 6000 records.
# Insertion round 573 6000 records.
# Insertion round 574 6000 records.
# Insertion round 575 6000 records.
# Insertion round 576 6000 records.
# Insertion round 577 6000 records.
# Insertion round 578 6000 records.
# Insertion round 579 6000 records.
# Insertion round 580 6000 records.
# Insertion round 581 6000 records.
# Insertion round 582 6000 records.
# Insertion round 583 6000 records.
# Insertion round 584 6000 records.
# Insertion round 585 6000 records.
# Insertion round 586 6000 records.
# Insertion round 587 6000 records.
# Insertion round 588 6000 records.
# Insertion round 589 6000 records.
# Insertion round 590 6000 records.
# Insertion round 591 6000 records.
# Insertion round 592 6000 records.
# Insertion round 593 6000 records.
# Insertion round 594 6000 records.
# Insertion round 595 6000 records.
# Insertion round 596 6000 records.
# Insertion round 597 6000 records.
# Insertion round 598 6000 records.
# Insertion round 599 6000 records.
# Insertion round 600 6000 records.
# Insertion round 601 6000 records.
# Insertion round 602 6000 records.
# Insertion round 603 6000 records.
# Insertion round 604 6000 records.
# Insertion round 605 6000 records.
# Insertion round 606 6000 records.
# Insertion round 607 6000 records.
# Insertion round 608 6000 records.
# Insertion round 609 6000 records.
# Insertion round 610 6000 records.
# Insertion round 611 6000 records.
# Insertion round 612 6000 records.
# Insertion round 613 6000 records.
# Insertion round 614 6000 records.
# Insertion round 615 6000 records.
# Insertion round 616 6000 records.
# Insertion round 617 6000 records.
# Insertion round 618 6000 records.
# Insertion round 619 6000 records.
# Insertion round 620 6000 records.
# Insertion round 621 6000 records.
# Insertion round 622 6000 records.
# Insertion round 623 6000 records.
# Insertion round 624 6000 records.
# Insertion round 625 6000 records.
# Insertion round 626 6000 records.
# Insertion round 627 6000 records.
# Insertion round 628 6000 records.
# Insertion round 629 6000 records.
# Insertion round 630 6000 records.
# Insertion round 631 6000 records.
# Insertion round 632 6000 records.
# Insertion round 633 6000 records.
# Insertion round 634 6000 records.
# Insertion round 635 6000 records.
# Insertion round 636 6000 records.
# Insertion round 637 6000 records.
# Insertion round 638 6000 records.
# Insertion round 639 6000 records.
# Insertion round 640 6000 records.
# Insertion round 641 6000 records.
# Insertion round 642 6000 records.
# Insertion round 643 6000 records.
# Insertion round 644 6000 records.
# Insertion round 645 6000 records.
# Insertion round 646 6000 records.
# Insertion round 647 6000 records.
# Insertion round 648 6000 records.
# Insertion round 649 6000 records.
# Insertion round 650 6000 records.
# Insertion round 651 6000 records.
# Insertion round 652 6000 records.
# Insertion round 653 6000 records.
# Insertion round 654 6000 records.
# Insertion round 655 6000 records.
# Insertion round 656 6000 records.
# Insertion round 657 6000 records.
# Insertion round 658 6000 records.
# Insertion round 659 6000 records.
# Insertion round 660 6000 records.
# Insertion round 661 6000 records.
# Insertion round 662 6000 records.
# Insertion round 663 6000 records.
# Insertion round 664 6000 records.
# Insertion round 665 6000 records.
# Insertion round 666 6000 records.
# Insertion round 667 6000 records.
# Insertion round 668 6000 records.
# Insertion round 669 6000 records.
# Insertion round 670 6000 records.
# Insertion round 671 6000 records.
# Insertion round 672 6000 records.
# Insertion round 673 6000 records.
# Insertion round 674 6000 records.
# Insertion round 675 6000 records.
# Insertion round 676 6000 records.
# Insertion round 677 6000 records.
# Insertion round 678 6000 records.
# Insertion round 679 6000 records.
# Insertion round 680 6000 records.
# Insertion round 681 6000 records.
# Insertion round 682 6000 records.
# Insertion round 683 6000 records.
# Insertion round 684 6000 records.
# Insertion round 685 6000 records.
# Insertion round 686 6000 records.
# Insertion round 687 6000 records.
# Insertion round 688 6000 records.
# Insertion round 689 6000 records.
# Insertion round 690 6000 records.
# Insertion round 691 6000 records.
# Insertion round 692 6000 records.
# Insertion round 693 6000 records.
# Insertion round 694 6000 records.
# Insertion round 695 6000 records.
# Insertion round 696 6000 records.
# Insertion round 697 6000 records.
# Insertion round 698 6000 records.
# Insertion round 699 6000 records.
# Insertion round 700 6000 records.
# Insertion round 701 6000 records.
# Insertion round 702 6000 records.
# Insertion round 703 6000 records.
# Insertion round 704 6000 records.
# Insertion round 705 6000 records.
# Insertion round 706 6000 records.
# Insertion round 707 6000 records.
# Insertion round 708 6000 records.
# Insertion round 709 6000 records.
# Insertion round 710 6000 records.
# Insertion round 711 6000 records.
# Insertion round 712 6000 records.
# Insertion round 713 6000 records.
# Insertion round 714 6000 records.
# Insertion round 715 6000 records.
# Insertion round 716 6000 records.
# Insertion round 717 6000 records.
# Insertion round 718 6000 records.
# Insertion round 719 6000 records.
# Insertion round 720 6000 records.
# Insertion round 721 6000 records.
# Insertion round 722 6000 records.
# Insertion round 723 6000 records.
# Insertion round 724 6000 records.
# Insertion round 725 6000 records.
# Insertion round 726 6000 records.
# Insertion round 727 6000 records.
# Insertion round 728 6000 records.
# Insertion round 729 6000 records.
# Insertion round 730 6000 records.
# Insertion round 731 6000 records.
# Insertion round 732 6000 records.
# Insertion round 733 6000 records.
# Insertion round 734 6000 records.
# Insertion round 735 6000 records.
# Insertion round 736 6000 records.
# Insertion round 737 6000 records.
# Insertion round 738 6000 records.
# Insertion round 739 6000 records.
# Insertion round 740 6000 records.
# Insertion round 741 6000 records.
# Insertion round 742 6000 records.
# Insertion round 743 6000 records.
# Insertion round 744 6000 records.
# Insertion round 745 6000 records.
# Insertion round 746 6000 records.
# Insertion round 747 6000 records.
# Insertion round 748 6000 records.
# Insertion round 749 6000 records.
# Insertion round 750 6000 records.
# Insertion round 751 6000 records.
# Insertion round 752 6000 records.
# Insertion round 753 6000 records.
# Insertion round 754 6000 records.
# Insertion round 755 6000 records.
# Insertion round 756 6000 records.
# Insertion round 757 6000 records.
# Insertion round 758 6000 records.
# Insertion round 759 6000 records.
# Insertion round 760 6000 records.
# Insertion round 761 6000 records.
# Insertion round 762 6000 records.
# Insertion round 763 6000 records.
# Insertion round 764 6000 records.
# Insertion round 765 6000 records.
# Insertion round 766 6000 records.
# Insertion round 767 6000 records.
# Insertion round 768 6000 records.
# Insertion round 769 6000 records.
# Insertion round 770 6000 records.
# Insertion round 771 6000 records.
# Insertion round 772 6000 records.
# Insertion round 773 6000 records.
# Insertion round 774 6000 records.
# Insertion round 775 6000 records.
# Insertion round 776 6000 records.
# Insertion round 777 6000 records.
# Insertion round 778 6000 records.
# Insertion round 779 6000 records.
# Insertion round 780 6000 records.
# Insertion round 781 6000 records.
# Insertion round 782 6000 records.
# Insertion round 783 6000 records.
# Insertion round 784 6000 records.
# Insertion round 785 6000 records.
# Insertion round 786 6000 records.
# Insertion round 787 6000 records.
# Insertion round 788 6000 records.
# Insertion round 789 6000 records.
# Insertion round 790 6000 records.
# Insertion round 791 6000 records.
# Insertion round 792 6000 records.
# Insertion round 793 6000 records.
# Insertion round 794 6000 records.
# Insertion round 795 6000 records.
# Insertion round 796 6000 records.
# Insertion round 797 6000 records.
# Insertion round 798 6000 records.
# Insertion round 799 6000 records.
# Insertion round 800 6000 records.
# Insertion round 801 6000 records.
# Insertion round 802 6000 records.
# Insertion round 803 6000 records.
# Insertion round 804 6000 records.
# Insertion round 805 6000 records.
# Insertion round 806 6000 records.
# Insertion round 807 6000 records.
# Insertion round 808 6000 records.
# Insertion round 809 6000 records.
# Insertion round 810 6000 records.
# Insertion round 811 6000 records.
# Insertion round 812 6000 records.
# Insertion round 813 6000 records.
# Insertion round 814 6000 records.
# Insertion round 815 6000 records.
# Insertion round 816 6000 records.
# Insertion round 817 6000 records.
# Insertion round 818 6000 records.
# Insertion round 819 6000 records.
# Insertion round 820 6000 records.
# Insertion round 821 6000 records.
# Insertion round 822 6000 records.
# Insertion round 823 6000 records.
# Insertion round 824 6000 records.
# Insertion round 825 6000 records.
# Insertion round 826 6000 records.
# Insertion round 827 6000 records.
# Insertion round 828 6000 records.
# Insertion round 829 6000 records.
# Insertion round 830 6000 records.
# Insertion round 831 6000 records.
# Insertion round 832 6000 records.
# Insertion round 833 6000 records.
# Insertion round 834 6000 records.
# Insertion round 835 6000 records.
# Insertion round 836 6000 records.
# Insertion round 837 6000 records.
# Insertion round 838 6000 records.
# Insertion round 839 6000 records.
# Insertion round 840 6000 records.
# Insertion round 841 6000 records.
# Insertion round 842 6000 records.
# Insertion round 843 6000 records.
# Insertion round 844 6000 records.
# Insertion round 845 6000 records.
# Insertion round 846 6000 records.
# Insertion round 847 6000 records.
# Insertion round 848 6000 records.
# Insertion round 849 6000 records.
# Insertion round 850 6000 records.
# Insertion round 851 6000 records.
# Insertion round 852 6000 records.
# Insertion round 853 6000 records.
# Insertion round 854 6000 records.
# Insertion round 855 6000 records.
# Insertion round 856 6000 records.
# Insertion round 857 6000 records.
# Insertion round 858 6000 records.
# Insertion round 859 6000 records.
# Insertion round 860 6000 records.
# Insertion round 861 6000 records.
# Insertion round 862 6000 records.
# Insertion round 863 6000 records.
# Insertion round 864 6000 records.
# Insertion round 865 6000 records.
# Insertion round 866 6000 records.
# Insertion round 867 6000 records.
# Insertion round 868 6000 records.
# Insertion round 869 6000 records.
# Insertion round 870 6000 records.
# Insertion round 871 6000 records.
# Insertion round 872 6000 records.
# Insertion round 873 6000 records.
# Insertion round 874 6000 records.
# Insertion round 875 6000 records.
# Insertion round 876 6000 records.
# Insertion round 877 6000 records.
# Insertion round 878 6000 records.
# Insertion round 879 6000 records.
# Insertion round 880 6000 records.
# Insertion round 881 6000 records.
# Insertion round 882 6000 records.
# Insertion round 883 6000 records.
# Insertion round 884 6000 records.
# Insertion round 885 6000 records.
# Insertion round 886 6000 records.
# Insertion round 887 6000 records.
# Insertion round 888 6000 records.
# Insertion round 889 6000 records.
# Insertion round 890 6000 records.
# Insertion round 891 6000 records.
# Insertion round 892 6000 records.
# Insertion round 893 6000 records.
# Insertion round 894 6000 records.
# Insertion round 895 6000 records.
# Insertion round 896 6000 records.
# Insertion round 897 6000 records.
# Insertion round 898 6000 records.
# Insertion round 899 6000 records.
# Insertion round 900 6000 records.
# Insertion round 901 6000 records.
# Insertion round 902 6000 records.
# Insertion round 903 6000 records.
# Insertion round 904 6000 records.
# Insertion round 905 6000 records.
# Insertion round 906 6000 records.
# Insertion round 907 6000 records.
# Insertion round 908 6000 records.
# Insertion round 909 6000 records.
# Insertion round 910 6000 records.
# Insertion round 911 6000 records.
# Insertion round 912 6000 records.
# Insertion round 913 6000 records.
# Insertion round 914 6000 records.
# Insertion round 915 6000 records.
# Insertion round 916 6000 records.
# Insertion round 917 6000 records.
# Insertion round 918 6000 records.
# Insertion round 919 6000 records.
# Insertion round 920 6000 records.
# Insertion round 921 6000 records.
# Insertion round 922 6000 records.
# Insertion round 923 6000 records.
# Insertion round 924 6000 records.
# Insertion round 925 6000 records.
# Insertion round 926 6000 records.
# Insertion round 927 6000 records.
# Insertion round 928 6000 records.
# Insertion round 929 6000 records.
# Insertion round 930 6000 records.
# Insertion round 931 6000 records.
# Insertion round 932 6000 records.
# Insertion round 933 6000 records.
# Insertion round 934 6000 records.
# Insertion round 935 6000 records.
# Insertion round 936 6000 records.
# Insertion round 937 6000 records.
# Insertion round 938 6000 records.
# Insertion round 939 6000 records.
# Insertion round 940 6000 records.
# Insertion round 941 6000 records.
# Insertion round 942 6000 records.
# Insertion round 943 6000 records.
# Insertion round 944 6000 records.
# Insertion round 945 6000 records.
# Insertion round 946 6000 records.
# Insertion round 947 6000 records.
# Insertion round 948 6000 records.
# Insertion round 949 6000 records.
# Insertion round 950 6000 records.
# Insertion round 951 6000 records.
# Insertion round 952 6000 records.
# Insertion round 953 6000 records.
# Insertion round 954 6000 records.
# Insertion round 955 6000 records.
# Insertion round 956 6000 records.
# Insertion round 957 6000 records.
# Insertion round 958 6000 records.
# Insertion round 959 6000 records.
# Insertion round 960 6000 records.
# Insertion round 961 6000 records.
# Insertion round 962 6000 records.
# Insertion round 963 6000 records.
# Insertion round 964 6000 records.
# Insertion round 965 6000 records.
# Insertion round 966 6000 records.
# Insertion round 967 6000 records.
# Insertion round 968 6000 records.
# Insertion round 969 6000 records.
# Insertion round 970 6000 records.
# Insertion round 971 6000 records.
# Insertion round 972 6000 records.
# Insertion round 973 6000 records.
# Insertion round 974 6000 records.
# Insertion round 975 6000 records.
# Insertion round 976 6000 records.
# Insertion round 977 6000 records.
# Insertion round 978 6000 records.
# Insertion round 979 6000 records.
# Insertion round 980 6000 records.
# Insertion round 981 6000 records.
# Insertion round 982 6000 records.
# Insertion round 983 6000 records.
# Insertion round 984 6000 records.
# Insertion round 985 6000 records.
# Insertion round 986 6000 records.
# Insertion round 987 6000 records.
# Insertion round 988 6000 records.
# Insertion round 989 6000 records.
# Insertion round 990 6000 records.
# Insertion round 991 6000 records.
# Insertion round 992 6000 records.
# Insertion round 993 6000 records.
# Insertion round 994 6000 records.
# Insertion round 995 6000 records.
# Insertion round 996 6000 records.
# Insertion round 997 6000 records.
# Insertion round 998 6000 records.
# Insertion round 999 6000 records.
# Insertion round 1000 6000 records.
# Successfully inserted 6000000 records into the database.
# Finished inserting!!!

# %% [markdown]
# ## Sample Data Users

# %%
# import random
# import string
# import mysql.connector  # Replace with your database connector library (e.g., psycopg2 for PostgreSQL)

# # Database connection details (replace with your credentials)
# DB_HOST = "localhost"
# DB_USER = "root"
# DB_PASSWORD = ""
# DB_NAME = "big_data_db"

# # Function to generate random data (you can customize this)
# def generate_data():
#     name = ''.join(random.choice(string.ascii_uppercase + string.digits) for _ in range(10))
#     email = f"{name.lower()}@{random.randint(1, 100)}.com"
#     age = random.randint(18, 65)
#     return name, email, age

# # Connect to the database
# try:
#     connection = mysql.connector.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWORD, database=DB_NAME)
#     cursor = connection.cursor()
# except mysql.connector.Error as err:
#     print("Error connecting to database:", err)
#     exit()

# # Create table if it doesn't exist (replace with your table schema)
# create_table_query = """
# CREATE TABLE IF NOT EXISTS users (
#   id INT AUTO_INCREMENT PRIMARY KEY,
#   name VARCHAR(255) NOT NULL,
#   email VARCHAR(255) NOT NULL UNIQUE,
#   age INT NOT NULL
# )
# """
# cursor.execute(create_table_query)
# connection.commit()

# # Generate and insert data
# print('Start inserting ...')
# insertion_amount = 100
# num_records = 100000
# i = 0
# for k in range(insertion_amount):
#     for _ in range(num_records):
#         name, email, age = generate_data()
#         insert_query = """
#         INSERT INTO users (name, email, age)
#         VALUES (%s, %s, %s)
#         """
#         cursor.execute(insert_query, (name, email, age))
#     connection.commit()
#     i = i + 1
#     print('Insertion round', i, num_records, 'records.')

# print(f"Successfully inserted {num_records*insertion_amount} records into the database.")

# # Close the connection
# cursor.close()
# connection.close()

# print('Finished inserting!!!')
